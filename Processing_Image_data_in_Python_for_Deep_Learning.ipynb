# %% [markdown]
# <a href="https://colab.research.google.com/github/pb-roshith/Processing-Image-data-in-Python-for-Deep-Learning/blob/main/Processing_Image_data_in_Python_for_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/images (2).jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[211, 195, 182],
#         [211, 195, 182],
#         [212, 196, 183],
#         ...,
#         [229, 224, 221],
#         [229, 224, 221],
#         [229, 224, 221]],
#
#        [[211, 195, 182],
#         [211, 195, 182],
#         [212, 196, 183],
#         ...,
#         [229, 224, 221],
#         [229, 224, 221],
#         [229, 224, 221]],
#
#        [[211, 195, 182],
#         [212, 196, 183],
#         [213, 197, 184],
#         ...,
#         [229, 224, 221],
#         [229, 224, 221],
#         [229, 224, 221]],
#
#        ...,
#
#        [[201, 183, 169],
#         [201, 183, 169],
#         [201, 183, 169],
#         ...,
#         [214, 186, 165],
#         [214, 186, 165],
#         [214, 186, 165]],
#
#        [[199, 181, 167],
#         [199, 181, 167],
#         [200, 182, 168],
#         ...,
#         [215, 187, 165],
#         [215, 187, 165],
#         [215, 187, 165]],
#
#        [[199, 181, 167],
#         [199, 181, 167],
#         [200, 182, 168],
# ...

# %%
img.shape
# Out:
# (194, 259, 3)

# %%
img_plot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
im = Image.open('/content/images (2).jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>

# %%
im_resize = im.resize((100,100))

# %%
im_resize
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
im_resize.save('dog_resize.jpg')

# %%
im_r = mpimg.imread('/content/dog_resize.jpg')
img_plot = plt.imshow(im_r)
plt.show()

# %%
im_r.shape
# Out:
# (100, 100, 3)

# %%
import cv2

# %%
img = cv2.imread('/content/images (2).jpg')

# %%
img
# Out:
# array([[[182, 195, 211],
#         [182, 195, 211],
#         [183, 196, 212],
#         ...,
#         [221, 224, 229],
#         [221, 224, 229],
#         [221, 224, 229]],
#
#        [[182, 195, 211],
#         [182, 195, 211],
#         [183, 196, 212],
#         ...,
#         [221, 224, 229],
#         [221, 224, 229],
#         [221, 224, 229]],
#
#        [[182, 195, 211],
#         [183, 196, 212],
#         [184, 197, 213],
#         ...,
#         [221, 224, 229],
#         [221, 224, 229],
#         [221, 224, 229]],
#
#        ...,
#
#        [[169, 183, 201],
#         [169, 183, 201],
#         [169, 183, 201],
#         ...,
#         [165, 186, 214],
#         [165, 186, 214],
#         [165, 186, 214]],
#
#        [[167, 181, 199],
#         [167, 181, 199],
#         [168, 182, 200],
#         ...,
#         [165, 187, 215],
#         [165, 187, 215],
#         [165, 187, 215]],
#
#        [[167, 181, 199],
#         [167, 181, 199],
#         [168, 182, 200],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
gray
# Out:
# array([[193, 193, 194, ..., 224, 224, 224],
#        [193, 193, 194, ..., 224, 224, 224],
#        [193, 194, 195, ..., 224, 224, 224],
#        ...,
#        [181, 181, 181, ..., 183, 183, 183],
#        [179, 179, 180, ..., 184, 184, 184],
#        [179, 179, 180, ..., 184, 184, 184]], dtype=uint8)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=259x194>

# %%
cv2.imwrite('dog_gray.jpg', gray)
# Out:
# True

# %%
gray.shape
# Out:
# (194, 259)
